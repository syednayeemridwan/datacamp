# %% [markdown]
# # Looping through lists

# %% [markdown]
# In this exercise, the list things is provided for you. It contains multiple different types of Python objects. You need to loop through the items in the list. Which method is the best way to start the for loop?

# %% [markdown]
# - `for item in things:`

# %% [markdown]
# # Overlaying multiple plots on a figure

# %% [markdown]
# The City of Seattle has meters installed along the Fremont Bridge that log bicycle traffic on both the East and West side of the bridge, which runs North and South.
#
# In this exercise, you'll use for loops and matplotlib to explore how the traffic on the East and West sides of the bridge change during the day. Understanding how the two sides of the bridge get used during the morning and evening commute is important for any future development into cycling infrastructure that connects to this high traffic route.

# %%
# sidewalk = ['East','West']

# # Explore the shape of the array weekday_traffic
# print(weekday_traffic.shape)

# # Loop over the columns of weekday_traffic, counting the number of iterations
# for ii, sidewalk_traffic in enumerate(weekday_traffic.T):
#     # Plot the column with the corresponding label in sidewalk
#     plt.plot(sidewalk_traffic, label=sidewalk[ii])
    
# # Create the legend and show the plot
# plt.legend()
# plt.show()

# %% [markdown]
# # Counting different types of aircraft

# %% [markdown]
# For this exercise, you have a dictionary, aircraft_engines that contains the engine type of a number of popular commercial airplanes. You want to count how many airplanes of each engine type exist in this dataset. Use your Python control flow skills by creating a for loop that contains an if/else statement that adds 1 to the counts variable for every new engine type.

# %%
airplane_types = {'B-737-700': 'Turbofan',
 'A-320': 'Turbofan',
 'B-737-800': 'Turbofan',
 'C-172': 'Reciprocating',
 'CRJ100/200': 'Turbofan',
 'B-757-200': 'Turbofan',
 'A-319': 'Turbofan',
 'CRJ700': 'Turbofan',
 'B-767-300': 'Turbofan',
 'B-737': 'Turbofan',
 'B-737-300': 'Turbofan',
 'MD-80': 'Turbofan',
 'EMB-120': 'Turboprop',
 'B-737-500': 'Turbofan'}

counts = {}
# Loop over the key:value pairs in airplane_types
for airplane, engine_type in airplane_types.items():
    # Print the aircraft name and engine type of each aircraft
    print("The {} airplane has {} engines.".format(airplane, engine_type))
    # Increment the values of the engine_type key in the counts dictionary
    if engine_type in counts:
        counts[engine_type] = counts[engine_type] + 1
    else:
        counts[engine_type] = 1

print(counts)
# Out:
# The B-737-700 airplane has Turbofan engines.
# The A-320 airplane has Turbofan engines.
# The B-737-800 airplane has Turbofan engines.
# The C-172 airplane has Reciprocating engines.
# The CRJ100/200 airplane has Turbofan engines.
# The B-757-200 airplane has Turbofan engines.
# The A-319 airplane has Turbofan engines.
# The CRJ700 airplane has Turbofan engines.
# The B-767-300 airplane has Turbofan engines.
# The B-737 airplane has Turbofan engines.
# The B-737-300 airplane has Turbofan engines.
# The MD-80 airplane has Turbofan engines.
# The EMB-120 airplane has Turboprop engines.
# The B-737-500 airplane has Turbofan engines.
# {'Turbofan': 12, 'Reciprocating': 1, 'Turboprop': 1}

# %% [markdown]
# # Finding certain rows in a DataFrame

# %% [markdown]
# Bird strikes by aircraft are both dangerous to human life and of great concern to conservation efforts. Luckily, the Federal Aviation Administration has been tracking wildlife strikes for nearly 30 years.
#
# You're going to use for loops to explore the FAA Wildlife Strikes database. A pandas DataFrame that contains wildlife strikes by aircraft in California recorded from 1990 to 2018 is loaded into your session. You want to find incidences that involve Snowy egrets, a migratory bird that winters in California.

# %%
import pandas as pd
wildlife_strikes = pd.read_csv("dataset/FAA_wildlife_strikes_CA.csv")

# Print the first few lines of the wildlife_strikes DataFrame
# print(wildlife_strikes.head())

# Loop through each row in wildlife_strikes
for i, row in wildlife_strikes.iterrows():
    # Use an if statement to check the species of this row
    if row['SPECIES']=='Snowy egret':
        # Print the INCIDENT_DATE, AIRPORT, ATYPE, and DAMAGE
        print(row['INCIDENT_DATE'],
              row['AIRPORT'],
              row['ATYPE'],
              row['DAMAGE'])
# Out:
# 2018-03-19 LOS ANGELES INTL B-777-200 None
# 2017-11-23 METRO OAKLAND INTL B-777-200 Minor
# 2017-08-20 LOS ANGELES INTL UNKNOWN nan
# 2017-05-02 LONG BEACH-DAUGH FLD UNKNOWN nan
# 2002-05-14 METRO OAKLAND INTL UNKNOWN nan
# 2000-01-02 SAN FRANCISCO INTL ARPT B-737-500 None

# %% [markdown]
# # Boolean indexing for quick stats

# %% [markdown]
# Let's return to the animals dataset, which is loaded as a list of dictionaries. You're going to use all you've learned and transform this data into a useable DataFrame, filter the data using Boolean indexing, and then perform some numpy magic to find out some interesting animal facts.

# %%
# import numpy as np
# # Create a DataFrame from animals
# animals = pd.DataFrame(animals)

# # Create Boolean indices for mammals and birds
# mammals = animals['Class']=='Mammalia'
# birds = animals['Class']=='Aves'

# # Use numpy and the Boolean indices to determine mean Litter/Clutch size
# litter = np.mean(animals[mammals]['Litter/Clutch size'])
# clutch = np.mean(animals[birds]['Litter/Clutch size'])

# # Print the average Litter/Clutch size of each class
# print('Mammals have an average of {} offspring in each litter.'.format(round(litter, 2)))
# print('The average clutch size in a single brood is {} eggs.'.format(round(clutch, 2)))

# %% [markdown]
# # Booleans for the win!

# %% [markdown]
# Time for a showdown! In this exercise, you'll compare looping over a pandas' DataFrame and Boolean indexing head-to-head.
#
# First, loop over the rows of the wildlife_strikes DataFrame and print the following information about the strike if it involved a Snowy egret, a migratory bird native to North and South America. Then, compare this method with Boolean indexing and print the same information on the subset DataFrame.

# %%
# # Loop through wildlife_strikes and print snowy egret data
# for i, row in wildlife_strikes.iterrows():
#     if row['SPECIES']=='Snowy egret':
#         print(row['INCIDENT_DATE'],
#               row['AIRPORT'],
#               row['ATYPE'],
#               row['DAMAGE'])

# # Create a Boolean index of snowy egrets onlys
# snowy_egret_index = wildlife_strikes['SPECIES']=='Snowy egret'

# # Subset the wildlife_strikes dataset
# snowy_egret = wildlife_strikes[snowy_egret_index]

# # Print the incident date, airport, atype, and damage in snowy_egret dataset
# print(snowy_egret[['INCIDENT_DATE', 'AIRPORT', 'ATYPE', 'DAMAGE']])

# %% [markdown]
# # Boolean indexing and Matplotlib fun

# %% [markdown]
# Now let's look at how Boolean indexing can help us explore data visually in just a few lines of code. In this exercise, you'll practice many of the things you've learned - converting data from a dictionary into a useable pandas' DataFrame, indexing using Booleans, and then using matplotlib to visualize your data to learn about some relationships in the wildlife strikes data.

# %%
# # Create a dictionary and then a DataFrame from the dictionary
# strikes = {'Date': date,'Speed': speed,'Height':height,'Engine':engine}
# strikes = pd.DataFrame(strikes)

# # Filter strikes by engine type
# turbofan = strikes['Engine']=='Turbofan'
# turboprop = strikes['Engine']=='Turboprop'

# # Create scatter plot of speed and height for each engine type
# plt.scatter(strikes[turbofan]['Speed'],strikes[turbofan]['Height'],label='Turbofan')
# plt.scatter(strikes[turboprop]['Speed'],strikes[turboprop]['Height'],label='Turboprop')
# plt.legend()
# plt.xlabel('Strike speed (knots)')
# plt.ylabel('Strike height (feet)')
# plt.show()
