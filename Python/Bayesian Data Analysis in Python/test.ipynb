# %%
import pandas as pd

# Example DataFrame
data = {
    'A': [1, 2, 3, 4],
    'B': [5, 6, 7, 8]
}
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
x = df.sort_values("B")
x = x.set_index("A")

# %%
x["B"]
# Out:
# A
# 1    5
# 2    6
# 3    7
# 4    8
# Name: B, dtype: int64

# %%
x["B"].max()
# Out:
# 8

# %%
import numpy as np
np.median(x["B"])
# Out:
# 6.5

# %%
y = x[x["B"] == x["B"].max()]
y
# Out:
#    B
# A
# 4  8

# %%
y.index.values[0]
# Out:
# 4
