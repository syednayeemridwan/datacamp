# %% [markdown]
# # Chapter 1

# %% [markdown]
# - Networks : Graphs
# - Important entities: influencers in social network
# - Pathfinding: most efficient transport path
# - Clustering: finding communities

# %% [markdown]
# <center><img src="images/01.01.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# <center><img src="images/01.02.png"  style="width: 400px, height: 300px;"/></center>
# <center><img src="images/01.03.png"  style="width: 400px, height: 300px;"/></center>
# <center><img src="images/01.04.png"  style="width: 400px, height: 300px;"/></center>
# <center><img src="images/01.05.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# ```
# import networkx as nx
# G = nx.Graph() # Initialize empty graph
# G = nx.erdos_renyi_graph(n=20, p=0.2) # Generate graph with randomly connected nodes
# G.add_nodes_from([1, 2, 3]) # Create 3 nodes in the graph
# G.add_edges_from(zip([node]*len(list(G.neighbors(node))), G.neighbors(node))) # Add edges between multiple nodes
# G.nodes() # See all nodes
# len(G.nodes()) # See no of nodes nodes
# G.nodes(data=True) # See all nodes with data
# list(G.neighbors(5)) # Find all nodes that are connected with node 5
# nx.degree_centrality(G) # actual neighbours of a node / total possible neighbours for that node, dict
# list(nx.degree_centrality(G).values()) # find values of degree of centrality, use histogram to get idea
# nx.betweenness_centrality(G) # total shortest paths through a given node / all possible shortest paths, dict
# list(nx.betweenness_centrality(G).values()) # find values of betweenness of centrality
# G.add_edge(1, 10) # Create edge between node 1 and 10
# G.edges[1,10]['weight'] = 2 # provide info / weight for edge between  1 and 10, can be considered a dictionary
# G.edges() # See all edges
# list(G.edges(data=True)) # See all edges in list along with data
# G.has_edge(node1, node2) # Check if there is any edge between 2 nodes
# G.nodes[1]['label'] = 'blue' # provide information for node 1, each node can be considered a dictionary
# nx.degree(G,n) # Get degree of node n in graph G
# G.nodes[n]['degree'] = nx.degree(G,n)
# nx.draw(G, with_labels=True) # Draw a graph with labels
# list(nx.find_cliques(G)) # Find maximal cliques
# import matplotlib.pyplot as plt
# plt.show()
# nx.triangles(G) # Which nodes form how many triangles cliques
# G = nx.Graph() # Non-directional graph
# D = nx.DiGraph() # Directional graph
# M = nx.MultiGraph() # Multi non-Directional graph
# MD = nx.MultiDiGraph() # Multi-Directional graph
# # Custom package for visualization
# import nxviz as nv # Find documentation for API at : https://ericmjl.github.io/nxviz/
# import matplotlib.pyplot as plt
# ap1 = nv.arc(G, sort_by='label1') # Visualize with arcplot, where nodes are ordered along axis and arc line defines relationship
# ap2 = nv.matrix(G, group_by='label2') # Visualize graph with matrixplot to see if an edge exists between pairs of nodes
# ap3 = nv.circos(G, node_color_by = 'label3') # Visualize graph with cicos plot, forms circle, used in genomics
# plt.show()
#
# # Convert T to a matrix format: A
# A = nx.to_numpy_matrix(T)
# # Convert A back to the NetworkX form as a directed graph: T_conv
# T_conv = nx.from_numpy_matrix(A, create_using=nx.DiGraph())
#
# # Find which graph a node resides in
# G.nodes()
# nodes = list(G.neighbors(8)) # Find the neighbors of a specified node
# nodes.append(8) # Add that node as well
# sub_G = G.subgraph(nodes) # Create a subgraph with the list of nodes
# list(nx.connected_components(G)) # list of subgraph dictionary that are disconnected but part of one graph
# ```

# %% [markdown]
# ### Visualizing graph

# %% [markdown]
# <center><img src="images/01.06.png"  style="width: 400px, height: 300px;"/></center>
# <center><img src="images/01.07.png"  style="width: 400px, height: 300px;"/></center>
# <center><img src="images/01.08.png"  style="width: 400px, height: 300px;"/></center>
# <center><img src="images/01.09.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Chapter 2

# %% [markdown]
# How important is a node or Which nodes are important? Calculate using:
#
# - Degree centrality
#
#   - Twitter broadcasters
#   - Airport transportation hubs
#   - Disease super-spreaders
#
# - Betweenness centrality
#   - Bridges between liberal- and conservative-leaning Twitter users
#   - Critical information transfer links

# %% [markdown]
# <center><img src="images/02.01.png"  style="width: 400px, height: 300px;"/></center>
# <center><img src="images/02.02.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Chapter 3

# %% [markdown]
# - Clique : a set of nodes where each node is connected with every other nodes, forming a graph
# - example application usage: If A knows B and A knows C, there is a good chance that B knows C (Triangle closures)
# - Maximal clique: The largest clique that is constructed by the participated nodes (sub-cliques of maximal cliques are not considered)

# %% [markdown]
# <center><img src="images/03.01.png"  style="width: 400px, height: 300px;"/></center>
# <center><img src="images/03.02.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# ### Combinations in python

# %% [markdown]
# ```
# from itertools import combinations
#
# comb = combinations([1, 1, 3], 2)
# print(list(combinations([1, 2, 3], 2)))
# # Output: [(1, 2), (1, 3), (2, 3)]
# ```

# %% [markdown]
# # Chapter 4

# %% [markdown]
# <center><img src="images/04.01.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# - Find important users: degree of centrality
# - Find largest communities of collaborators: largest cliques
# - Build a collaboration recommendation system: open triangles

# %% [markdown]
# ### Python sorting

# %% [markdown]
# ```
# cars = ['Ford', 'BMW', 'Volvo']
#
# cars.sort(reverse=True)
# # For a dataframe
# sorted_df = df.sort_values(by=['cat_col', 'num_col'], ascending=[True, False])
# each_group_top = sorted_df.groupby(['cat_col'])['num_col'].head(1) # top row of each category column
# # Sorted provides more way of customization... example with networkx
# sorted(nx.find_cliques(G), key=lambda x:len(x))[-1]
#
# ```
