# %% [markdown]
# # Chapter 1

# %% [markdown]
# - Review Slide for pictorial guidance

# %% [markdown]
# # Chapter 2

# %% [markdown]
# - PAT = password generated by github for defined usage time

# %% [markdown]
# # Chapter 3

# %% [markdown]
# - cloning : contains link to original repo (pushing change will reflect in original repo)
# - Forking : does not contain link to original repo (pushing change will reflect in your own copy of repo)
# - Assignee : Approves pull request
# - Reviewer : Looks at changes before pull request is merged

# %% [markdown]
# ### REVIEW SLIDES
