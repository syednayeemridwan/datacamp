# %% [markdown]
# # Using the proper primitive data type

# %% [markdown]
# You are tasked with modeling a simple book for a library. The library is interested in storing the number of pages of a book and knowing if it is rented. Keep in mind that the library has books with up to hundreds of thousands of pages.
#
# Write a program using OOP that will allow you to model the book as an object.

# %% [markdown]
# public class Main {
#     public static class Book {
#     	// Use the proper primitive data type
#         int pages;
#         // Use the proper primitive data type
#         boolean isRented;
#     }
#
#     public static void main(String[] args) {
#         Book book = new Book();
#     }
# }

# %% [markdown]
# # Checking books availability

# %% [markdown]
# While modeling the books for the library, they requested that you inform the end user if the book is available or rented. However, they want the book's number of pages printed while telling its rental status.
#
# Write a program that will meet their specific needs.

# %%
public class Main {
    public static class Book {
        int pages;
        boolean isRented;

        void checkIfRented() {
        	// Check if the book is rented
            if (isRented) { 
            	// Print the number of pages
                System.out.println("Book with " + pages + " pages is rented!"); 
            } else {
            	// Print the number of pages
                System.out.println("Book with " + pages + " pages is available!"); 
            }
        }
    }
    
    public static void main(String[] args) {
        Book book = new Book();
        book.checkIfRented();
    }
}

# %% [markdown]
# # What is a class?

# %% [markdown]
# Classes are one of the main concepts in OOP, and in Java, you'll always use them for a specific purpose.

# %% [markdown]
# <center><img src="images/01.01.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Modeling more complex books

# %% [markdown]
# While modeling the books for the library, they requested that books also contain the author's information.
#
# Write a program that will meet their specific needs.

# %%
public class Main {
    public static class Book {
        String name;
        int pages;
        // Add the author field as String
        String author;

        Book(String name, int pages, String author) {
            this.name = name;
            this.pages = pages;
            this.author = author;
        }
    }

    public static void main(String[] args) {
        // Create the Moby Dick object with Herman Melville as author
        Book mobyDick = new Book("Moby-Dick", 635, "Herman Melville");
    }
}

# %% [markdown]
# # Structure of a class

# %% [markdown]
# While writing Java code, you'll find that there are few restrictions on correctly ordering things. However, consistency and alignment with other's conventions are good ideas to make it easier for everyone to read and understand your code.
#
# Let's review the suggested order for the structure of a class in Java.

# %% [markdown]
# <center><img src="images/01.02.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Library management system: Class & fields

# %% [markdown]
# The management system is getting more traction, and now you were requested to add more information to the books.
#
# In this exercise, you'll write a program that allows the library to extend the attributes in the book model.

# %%
public class Main {
	// Create a class named `Book`
    public static class Book {
    	// Create the necessary fields
        int pages;
        String author;
        String title;
        boolean isRented;
    }

    public static void main(String[] args) {
        Book book = new Book();
    }
}

# %% [markdown]
# # Library management system: Constructor & methods

# %% [markdown]
# As the management system becomes more critical, you need to allow the creation of several different books and also inform if a book is rented.
#
# In this exercise, you'll write a program that allows the library to create different books using a constructor and validate whether a particular book is rented.

# %%
public class Main {

    public static class Book {
    	int pages;
        String author;
        String title;
        boolean isRented;

        public Book(String title, String author, int pages) {
            // Initialize all fields using the arguments as values
            this.title = title;
            this.author = author;
            this.pages = pages;
            // Initialize isRented field as false
            this.isRented = false;
        }
        
        // Complete method with name `checkIfRented` and without returning value
        void checkIfRented() {
            if (isRented) {
                System.out.println("Book is rented!");
            } else {
                System.out.println("Book is available!");
            }
        }
    }

    public static void main(String[] args) {
        // Create a new instance of a book with the given attributes
        Book book = new Book("Moby-Dick", "Herman Melville", 635);
        System.out.println("Book{title='" + book.title + ", author='" + book.author + "', pages=" + book.pages +  "}");
        book.checkIfRented();
    }
}
