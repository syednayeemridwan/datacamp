# %% [markdown]
# # Access modifiers in fields

# %% [markdown]
# As the management system becomes more critical, you must ensure proper security and design principles in your code.
#
# In this exercise, you'll select the proper access modifier for the fields.

# %%
public class Main {
    public static class Book {
    	// Set the access modifier for the fields
        private int pages;
        private String author;
        private String title;
        private boolean isRented;
    }

    public static void main(String[] args) {
    	// Create a new book
        Book book = new Book();
    }
}

# %% [markdown]
# # Access modifiers in methods

# %% [markdown]
# As the management system becomes more critical, you must ensure proper security and design principles in your code. Next, you address the access modifiers in the constructor and methods.
#
# In this exercise, you'll select the proper access modifier for the constructor and methods.

# %%
public class Main {
    public static class Book {
        private int pages;
        private String author;
        private String title;
        private boolean isRented;
        
        // Set the access modifier for the constructor
        public Book(String title, String author, int pages) {
        	this.pages = pages;
            this.author = author;
            this.title = title;
            this.isRented = false;
        }
        
        // Set the access modifier for the methods
        public void printDetails() {
        	System.out.println(prepareDetails());
        }
        
        private String prepareDetails() {
            return "Book{title='" + title + "', isRented=" + isRented + ", author='" + author + "', pages=" + pages +  "}";
        }
    }

    public static void main(String[] args) {
        Book book = new Book("Moby-Dick", "Herman Melville", 635);
        book.printDetails();
    }
}

# %% [markdown]
# # The first big expansion of the library

# %% [markdown]
# The library keeps expanding and now you'll need to start supporting more than just books!
#
# In general, you'd like to support several assets that will be rented. It could be books, CDs, or even movies.
#
# You need to create a proper design to avoid duplicating information among the assets.

# %%
public class Main {
    public static class Asset {
        String title;
        boolean isRented;
        public Asset(String title) {
            this.title = title;
            this.isRented = false;
        }
        // Default constructor
        public Asset() {}
    }
    // Extend the Asset class from the Book class
    public static class Book extends Asset {
        private String author;
        private int pages;
    }
    
    public static void main(String[] args) {}
}

# %% [markdown]
# # Access modifiers with inheritance

# %% [markdown]
# With the latest expansion of the library, you know that new assets will keep coming, so you need to make sure that the fields for the Asset class have a proper access modifier.
#
# Set the proper access modifier for the Asset class's fields to allow access to subclasses.

# %%
public class Main {
    public static class Asset {
    	// Set the proper access modifier
        protected String title;
        protected boolean isRented;
        public Asset(String title) {
            this.title = title;
            this.isRented = false;
        }
        // Default constructor
        public Asset() {}
    }

	public static class Book extends Asset {
        private String author;
        private int pages;
    }
    
    public static void main(String[] args) {}
}

# %% [markdown]
# # Abstract classes properties

# %% [markdown]
# Abstract classes are one of the key concepts to allow abstraction in Java, and thus one of the key concepts for OOP in Java.
#
# Classify the statements based on whether they describe an abstract class or not.

# %% [markdown]
# <center><img src="images/02.04.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Abstract asset

# %% [markdown]
# As the management system keeps evolving and new assets keep being added, you need to reduce code duplication but you don't want to allow the creation of assets as they on their own don't make sense.
#
# Make sure that it won't be possible to create an object from the Asset class.

# %%
public class Main {
	// Create the Asset class as an abstract class
    public abstract class Asset {
        String title;
        boolean isRented;
        public Asset(String title) {
            this.title = title;
            this.isRented = false;
        }
    }

    public static void main(String[] args) {}
}

# %% [markdown]
# # Datacamp modeling

# %% [markdown]
# Your colleague would like to understand more about the abstract classes, so you create the following example to showcase why abstract classes are so useful!

# %%
import java.util.Arrays;
import java.util.List;

public class Main {
    // Create abstract class Person
    public static abstract class Person {
        protected String name;
        public Person(String name) {
            this.name = name;
        }
        protected void sayHello() {
            System.out.println("Hello, " + name + "!");
        }
        public abstract void print();
    }
    // Extends from Person
    public static class Instructor extends Person {
        private List<String> coursesCreated;
        public Instructor(String name, List<String> coursesCreated) {
            super(name);
            this.coursesCreated = coursesCreated;
        }
        public void print() {
            sayHello();
            System.out.println("Instructor has created:");
            for (String course: coursesCreated) {
                System.out.println("\t- " + course);
            }
        }
    }
    // Extends from Person
    public static class Student extends Person {
        private String lastCourseTaken;
        public Student(String name, String lastCourseTaken) {
            super(name);
            this.lastCourseTaken = lastCourseTaken;
        }
        public void print() {
            sayHello();
            System.out.println("Student last taken course: " + lastCourseTaken);
        }
    }

    public static void main(String[] args) {
        Person miller = new Instructor("Miller", Arrays.asList("Understanding Modern Data Architecture", "Introduction to Object-Oriented Programming in Java"));
        miller.print();
        Person john = new Student("John Doe", "Understanding Modern Data Architecture");
        john.print();
    }
}

# %% [markdown]
# # Abstract class vs Interface

# %% [markdown]
# Both abstract classes and interfaces are used for the sake of abstraction. However, they have core differences.
#
# Classify the statements based on what concept they better describe between abstract class or interface.

# %% [markdown]
# <center><img src="images/02.05.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Supporting more than books in the library

# %% [markdown]
# As a programmer working for a local library, you are tasked with a significant project. The library needs a robust management system to manage its diverse collection of assets effectively. Each asset type has unique attributes, but they also share common properties like the title and behaviors. Your work will enable the library to track rented assets and facilitate the renting process.
#
# Write a program that allows the library to model the scenario for books. Make sure to use the toString() method to print all the details of each book.

# %%
public class Main {

    public interface Rentable {
        void rent();
    }
	// Implement the Rentable interface
    public abstract static class Asset implements Rentable {
        protected String title;
        protected boolean isRented;
        public Asset(String title) {
            this.title = title;
            this.isRented = false;
        }
        @Override
        public void rent() {
            if (!isRented) {
                isRented = true;
                System.out.println(title + " has been rented.");
            } else {
                System.out.println(title + " is already rented.");
            }
        }
    }

    public static class Book extends Asset {
        private String author;
        private int pages;

        public Book(String title, String author, int pages) {
        	// Initialize superclass
            super(title);
            this.author = author;
            this.pages = pages;
        }

        @Override
        public String toString() {
        	// Print the fields info
            return "Book{title='" + title + "', isRented=" + isRented + ", author='" + author + "', pages=" + pages +  "}";
        }
    }

    public static void main(String[] args) {
        Asset book = new Book("Moby-Dick", "Herman Melville", 635);
        System.out.println(book);
        book.rent();
        System.out.println(book);
    }
}
