# %% [markdown]
# # Using the Environment

# %% [markdown]
# Throughout this course, you will use Datacamp's development environment to write and run your Java code. In this first exercise, you get a chance to explore this environment and practice running a Java application.

# %%
# // You learned about class in the previous video
# class WelcomeToJava {

# 	// You'll learn about the main method next
#     public static void main (String[] args){
#     	// You'll learn about println statements too!
#     	System.out.println("Welcome to Introduction to Java!");
#     }
# }

# %% [markdown]
# # Commenting

# %% [markdown]
# Comments (or the act of commenting code) provide human readable information in the code so you (or your fellow developers) can remember what the code is about. In this exercise, you add some comments to some existing Java code.

# %%
# // This is a class
# class SecondJavaApp {

# 	// This is the kickoff
#     public static void main (String[] args){
#     	// This statement produces output
#     	System.out.println("Java ignores comments");
#     }
# }

# %% [markdown]
# # Recognizing Java Code Errors

# %% [markdown]
# Which of the following lines of Java code in this program are incorrect?
# ```
# (1) class FooBar {
# (2)     public static Main (String[] args)
# (3)       System.out.println("I am learning Java!")
# (4)     }
# (5) ]
# ```

# %% [markdown]
# - Line (2)
# - Line (3)
# - Line (5)
#
# ```
# (1) class FooBar {
# (2)     public static void Main (String[] args) {
# (3)       System.out.println("I am learning Java!");
# (4)     }
# (5) }
# ```

# %% [markdown]
# # Java Code Elements

# %% [markdown]
# It's important early in your Java journey to identify the basic building blocks of Java code. Where do the elements begin and end? What's it doing? Using comments, try to identify Java application elements you have already started to learn.

# %%
# // Class
# class HelloWorld {
#     // main method
#     public static void main(String[] args) {
#       // Print out statement
#       System.out.println("Hello World");
# 	// main method ends
# 	}
# // Class ends
# }

# %% [markdown]
# # Hello World!

# %% [markdown]
# When learning any programming language, the first program you create and run is typically the "Hello World" program - simply a computer program that outputs or displays "Hello World" to its user. In this exercise, you'll create "Hello World" in Java. You will create a program class, a main method and use System.out.println to display the "Hello World" message.

# %%
# // Start your class here
# public class HelloWorld{
#     public static void main(String[] args) {
# 		// Use a semi-colon to end Java statements like this one
#         System.out.println("Hello World");
#     }
# // Close out the class
# }

# %% [markdown]
# # Pick the Primitives

# %% [markdown]
# Which of the following are Java primitive values?

# %% [markdown]
# - 123D (double)
# - '#' (character)

# %% [markdown]
# # Variable Typing

# %% [markdown]
# When writing Java code, you have to decide what types will hold your variables. You know what data you are working with, but which type should you use? The primitive types are byte, short, int, long, float, double, char and boolean. Time now to start exercising that type picking skills. Pick the right variable type based on the variable value assigned.

# %%
# class PickType {
# 	public static void main (String[] args){
#       // Select the correct primitive type
#       char tshirtSize = 'M';
# 	  byte dressSize = 8;
# 	  boolean isOn = false;
# 	  float interestRate = 5.45f;
#     }
# }

# %% [markdown]
# # Assigning Variables

# %% [markdown]
# Declaring variables and assigning them values is a big part of any Java programmers day. Learn to get proficient with variables, types and assignment. As you have learned, Java has many primitive types. In this exercise, you define variables of those types and assign primitive values to them. The application then uses System.out.println to display the values stored in those variables.

# %%
# class HelloWorld {
#     public static void main(String[] args) {
#         // Define the nationalDebt variable
#         long nationalDebt = 34577128968551L;
#         // Define a temp variable
#         float temp = 98.6f;
#         double pi = 3.1415926535;
#         boolean isSmoker = false;
#         System.out.println(nationalDebt);
#         System.out.println(temp);
#         // Print out the value of pi
#         System.out.println(pi);
#         // Print out the value of isSmoker
#         System.out.println(isSmoker);
#     }
# }
