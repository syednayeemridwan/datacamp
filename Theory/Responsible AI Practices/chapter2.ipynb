# %% [markdown]
# # AI-specific risks

# %% [markdown]
# Imagine that you are running a business and want to explore AI to your company a competitive advantage.
#
# You look at some options to help elevate your business, such as utilizing a chatbot for your customer service department, or adopting an AI system to help your logistics department.
#
# You do some more research and identify some risks that other businesses have previously encountered.

# %% [markdown]
# <center><img src="images/02.12.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Misconceptions

# %% [markdown]
# As part of your research, you come across a number of untruths and misconceptions about AI in the workplace.
#
# Select three misconceptions about AI risks.

# %% [markdown]
# - AI can always be trusted to make unbiased decisions
# - AI does not require human oversight
# - AI’s environmental impact is negligible

# %% [markdown]
# # Risk levels

# %% [markdown]
# Imagine you are part of a team responsible for implementing AI systems at your company.
#
# The EU AI Act categorizes AI systems into four levels of risk: Minimal risk, Limited risk, High risk, and Unacceptable risk.
#
# Your task is to correctly identify the risk level of different AI systems, and arrange them accordingly.
# match the following order:
# - Minimal risk
# - Limited risk
# - High risk
# - Unacceptable risk

# %% [markdown]
# <center><img src="images/02.13.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # ISO Certification

# %% [markdown]
# Standardization is gaining more and more importance in the fast-developing world of AI. One well-known standard is ISO/IEC 42001.
#
# Imagine you are part of a team tasked with ensuring that your AI systems meet international standards. Understanding key standards like ISO/IEC 42001 is crucial for your role.
#
# Choose the best description of ISO/IEC 42001.

# %% [markdown]
# - ISO/IEC 42001 is an international standard that outlines how to manage and improve AI systems within organizations.

# %% [markdown]
# # AI oversight tools

# %% [markdown]
# As part of your mission to enhance AI governance within your company, you must implement effective oversight tools. These can help you ensure that your company's AI systems are both compliant and efficient.
#
# This task involves understanding the various existing frameworks, guidelines, and standards from different regions around the world.

# %% [markdown]
# <center><img src="images/02.14.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Balancing innovation with self-regulation

# %% [markdown]
# Imagine you are part of a committee tasked with developing ethical guidelines for AI within your organization. Understanding the role of self-regulation in responsible AI is crucial for your work.
#
# Which of these statements is true about self-regulation?

# %% [markdown]
# - Self-regulation is important for Responsible AI, since legislators can't keep up with the rapid pace of the developments.

# %% [markdown]
# # Tools for self-regulation

# %% [markdown]
# The committee you are part of wants to explore self-regulation further to enhance Responsible AI within your organization. Your task is to detail the different self-regulation tools available and describe the impact they can have on the organization.

# %% [markdown]
# <center><img src="images/02.15.png"  style="width: 400px, height: 300px;"/></center>
