# %% [markdown]
# # Separation of responsibilities

# %% [markdown]
# Recall that separation of responsibilities is an important concept in any programming paradigm and that it allows you to write modular code, which can save you time and energy in the long run. Each programming paradigm has a different mechanism for employing separation of responsibilities, and procedural programming is no exception.
#
# What is the mechanism by which procedural programming allows for separation of responsibilities and increased code modularity?

# %% [markdown]
# - Procedures

# %% [markdown]
# # Recognizing procedures

# %% [markdown]
# Great work so far understanding the basic unit of a procedural program: the procedure. You've seen that in Python, these procedures are implemented using Python functions. Now it's time to test your ability to recognize whether code is using procedures or not.

# %% [markdown]
# <center><img src="images/02.01.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Pros and cons of procedural programming

# %% [markdown]
# Imagine that your coworker has come to you with some questions about the project they are working on to apply discounts to the items in the online store and display the final prices to the user. They have mostly been working with procedural programming so far, but they recently learned that there are some other programming paradigms out there that might be more appropriate for their current project. They would like your advice about the pros and cons of procedural programming.

# %% [markdown]
# <center><img src="images/02.02.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Use cases for procedural programming

# %% [markdown]
# Imagine that you've been tasked with recommending a programming paradigm for your team's next big data analysis project. The team is leaning toward using procedural programming for the preparation step, but you want to make sure that's really the correct choice. As you talk through the requirements of the project with your team, you want to keep an eye out for factors that might make this an appropriate or inappropriate use case for procedural programming.

# %% [markdown]
# <center><img src="images/02.03.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Understanding control flow

# %% [markdown]
# Let's put that understanding of control flow to the test. You have a team member who needs some help writing a simple procedural program that will print out all of the names on her list, `names_list`, that start with the letter "A". Can you help her write a code snippet that achieves this?

# %%
names_list = ['Wesley', 'Amanda', 'Tori', 'Ngawang', 'Aviva']
for name in names_list:
    if name[0] == 'A':
        print(name)
# Out:
# Amanda
# Aviva

# %% [markdown]
# # Combine elements of control flow

# %% [markdown]
# Your coworker was so grateful that you were able to help her with her code for checking the list of names that she came back for more help! This time, she is specifically looking for code that will check all of the names in her list names_list and print them out if they are longer than ten letters. She is looking to wrap all of this into a function called print_long_names.

# %% [markdown]
# <center><img src="images/02.04.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Construct a basic procedural program

# %% [markdown]
# Now that you've learned the basics of procedural programming and reinforced those skills with some exercises, it's time to put it all together and build a procedural program! In the following exercise, you will take on the role of a programmer for a catering company, building a new order-taking system and testing it out on your own team first. You will be tasked with constructing a procedure to order a given person's lunch based on their preferences. After that, you will call this procedure as many times as you need to make all of the meals for your team!

# %%
# Define the order_lunch function (with three input parameters)
def order_lunch(name, sandwich_type, drink):
    lunch_order = name + ": One " + sandwich_type + " sandwich"
    if drink:
        lunch_order = lunch_order + " with a drink"
    return lunch_order


# Call the newly-defined function for each team member
alice_order = order_lunch("Alice", "PB&J", True)
venkata_order = order_lunch("Venkata", "Veggie", True)
maria_order = order_lunch("Maria", "Reuben", False)

# Print the outputs of the function calls
print(alice_order)
print(venkata_order)
print(maria_order)
# Out:
# Alice: One PB&J sandwich with a drink
# Venkata: One Veggie sandwich with a drink
# Maria: One Reuben sandwich
