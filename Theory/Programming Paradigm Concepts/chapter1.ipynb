# %% [markdown]
# # Understanding programming paradigms and languages

# %% [markdown]
# Now that you've seen the definitions of programming language and programming paradigm, and seen some examples of each, let's test your knowledge. It's important to understand how these two concepts relate to each other in order to make sense of the differences between various programming paradigms so that you can use them in your work.
#
# Which of the following statements is TRUE about programming languages and paradigms?

# %% [markdown]
# - Python can be used with multiple programming paradigms.

# %% [markdown]
# # Programming languages vs. programming paradigms

# %% [markdown]
# Great! You've successfully distinguished between true and false statements about programming paradigms and languages. Now you have someone on your team coming to you to ask about different programming paradigms, but it is clear that they are mixing up programming paradigms and languages. Can you classify the following characteristics and examples based on whether they describe or exemplify programming languages or programming paradigms in order to help them?

# %% [markdown]
# <center><img src="images/01.02.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Understanding categories of programming paradigms

# %% [markdown]
# Imagine that you are working on a program to solve a puzzle like Sudoku and need to decide which paradigm to use. You're going to start by determining whether you should use an imperative or declarative programming paradigm.
#
# Let's see if you can determine which of these statements about imperative and declarative programming are TRUE and which are FALSE.

# %% [markdown]
# <center><img src="images/01.03.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Comparing programming categories

# %% [markdown]
# Excellent! You've successfully identified some truths and falsehoods about imperative and declarative Programming, and now it's time to really focus in on the differences between the two. When you go on to learn about procedural programming, it will be helpful to know whether it is an example of imperative or declarative programming, as this will already give you a leg up in understanding how the paradigm works based on what you know about the category.

# %% [markdown]
# <center><img src="images/01.04.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Benefits of modular code

# %% [markdown]
# Imagine that you are working with a team of programmers and there is some debate about the importance of writing modular code and employing separation of responsibilities. You've recently studied this and have a list of the benefits prepared to share with the team in order to convince them to adopt this practice

# %% [markdown]
# <center><img src="images/01.05.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Benefits of thinking in multiple paradigms

# %% [markdown]
# Now you are working with a team of programmers that is debating which programming paradigm to use for a given problem. You don't know much about the different paradigms they're discussing yet, but you do know that there are some benefits to being able to think in multiple paradigms. You want to help your team understand this so that they can work together to select the most appropriate paradigm for the problem at hand.

# %% [markdown]
# <center><img src="images/01.06.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Identifying modular code in Python

# %% [markdown]
# You've learned about the separation of responsibilities and several reasons why writing modular code matters. You've also seen one example of what modular code can look like in Python. Can you recognize the example from the possible answers below that is making use of modular code?

# %%
# A
def get_higher_value(x, y):
    if x >= y:
        higher_value = x
    else:
        higher_value = y
    return higher_value


higher_value1 = get_higher_value(1, 2)
higher_value2 = get_higher_value(3, 4)

# %%
# B
x1 = 1
y1 = 2

if x1 >= y1:
    higher_value = x1
else:
    higher_value = y1

x2 = 1
y2 = 2

if x2 >= y2:
    higher_value = x2
else:
    higher_value = y2

# %% [markdown]
# - Code sample A demonstrates modular code, and code sample B does not.
