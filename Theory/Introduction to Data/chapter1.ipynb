# %% [markdown]
# # Structured vs. unstructured

# %% [markdown]
# Emma recently got hired at DataPrint, a small online store that sells printer equipment. She found a lot of data in the first week of her job and wanted to segregate it into structured or unstructured data.

# %% [markdown]
# <center><img src="images/01.01.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Quantitative vs. qualitative

# %% [markdown]
# Harry's reading collection is getting out of hand, so he is thinking of investing in a new bookshelf. He wants to make a list of qualitative and quantitative product descriptions for each bookshelf, so it's easier for him to compare the bookshelves and make a decision.
#
# Can you help Harry organize the description for an antique bookshelf he found on a second hand website?

# %% [markdown]
# <center><img src="images/01.02.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Data context

# %% [markdown]
# Which of the following is a characteristic of data context?

# %% [markdown]
# - The time frame in which the data was collected
# - The country where the data was collected
# - The specific problem or question the data is being used to address

# %% [markdown]
# # Data-driven vs. gut feelings

# %% [markdown]
# When it comes to business, decisions matter. Therefore, it's essential to recognize whether your choices are driven by data or gut feelings.

# %% [markdown]
# <center><img src="images/01.03.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Data-driven decision making

# %% [markdown]
# Due to advancements in modern technology, data-driven decisions are getting their roots across various industries.
#
# <center><img src="images/01.05.jpeg"  style="width: 400px, height: 300px;"/></center>
#
#
# Which of the following statements are (direct and indirect) benefits of a data-driven approach when making decisions?

# %% [markdown]
# - Transparency on business performance
# - Improved customer service
# - Increased accountability
# - Operational improvements
# - Improved data literacy

# %% [markdown]
# # Data storage capabilities

# %% [markdown]
# The recent improvements in data storage capabilities generated economic advantages for companies, but it also created some risks or drawbacks.

# %% [markdown]
# <center><img src="images/01.04.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Taking the right decisions

# %% [markdown]
# You are working for CreaSport, a company that sells racket sport related materials. They own the supply chain from A-Z, and process raw materials into finalized products. The products they manufacture and sell include tennis rackets, squash balls, etc.
#
# <center><img src="images/01.06.jpg"  style="width: 400px, height: 300px;"/></center>
#
# They're currently facing two key issues:
#
# - Out of stock material in stores
# - Selling products at a loss
#
# CreaSport is at the start of their data journey, and wants to become more competitive in the market. Which of the following are good ideas for them to pursue?

# %% [markdown]
# - Forecast sales per product(category) per store
# - Investigate which supply chain analytics software to invest in
# - Calculate profit margin (revenue - cost) per product
