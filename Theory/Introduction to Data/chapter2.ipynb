# %% [markdown]
# # Managing mental models

# %% [markdown]
# Mental models are useful for breaking down complex ideas into manageable parts. The DIKW framework is an example of a mental model. When applying the DIKW framework we perform steps at each level to advance to the next.
#
# Select all of the true statements regarding the DIKW framework.

# %% [markdown]
# - Create wisdom by uncovering connections between pieces of knowledge
# - Assemble raw data to serve as the foundation for the entire decision making process

# %% [markdown]
# # DIKW steps

# %% [markdown]
# The DIKW pyramid focuses on achieving wisdom through various steps throughout the framework.

# %% [markdown]
# <center><img src="images/02.04.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # The right decision

# %% [markdown]
# Bizvio corporation can't keep up with the high customer service tickets. Tickets are not getting resolved on time and customer satisfaction is dropping.
#
# The number of pending service requests is increasing every day. You are brought on to address this situation.
#
# Being a data-driven person, you decide to break the activity into the five data driven decision making steps to spot improvements easier.

# %% [markdown]
# <center><img src="images/02.05.png"  style="width: 400px, height: 300px;"/></center>

# %% [markdown]
# # Data driven decision making

# %% [markdown]
# Data-driven decision-making gives many advantages to individuals, businesses and organizations, by enhancing business growth and operational excellence, optimizing customer experience, innovating products and services, and empowering decisions with data.
#
# What is an objective of data-driven decision-making?

# %% [markdown]
# - Make a confident decisions
# - Refine company processes
# - Outline measurable business goals
# - Make decisions free from bias

# %% [markdown]
# # Aggregating information

# %% [markdown]
# Aggregations serve many purposes for individuals and organizations. They allow us to look at specific parts of a dataset and focus the insight discovery process.
#
# Select all the statements you should consider when working with an aggregation for the first time.

# %% [markdown]
# - It is important to understand the business logic behind an aggregation
# - Many different domains contribute to success of aggregations within an organization by ensuring data is high quality and reliable

# %% [markdown]
# # Data management

# %% [markdown]
# Data is a highly valuable asset to every organization. Managing that flow of data requires dedicated efforts from many different individuals to unlock the potential within our data streams.
#
# Understanding the role that each domain plays can help understand the complexities of the data all around you.
# Order the statements corresponding to the appropriate data domains.
#
# - Data Governance
# - Data Quality
# - Data Security and Privacy
# - Data Management

# %% [markdown]
# <center><img src="images/02.06.png"  style="width: 400px, height: 300px;"/></center>
